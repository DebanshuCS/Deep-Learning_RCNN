# %%
import os
from google.colab import drive
from keras.preprocessing.image import ImageDataGenerator
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/DeepLearning/rcnn')
# Out:
# Mounted at /content/drive

# %%
import os,cv2,keras
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %%
path = "images"
annot = "csv"

# %%
for e,i in enumerate(os.listdir(annot)):
    if e < 10:
        filename = i.split(".")[0]+".jpg"
        print(filename)
        img = cv2.imread(os.path.join(path,filename))
        df = pd.read_csv(os.path.join(annot,i))
        plt.imshow(img)
        for row in df.iterrows():
            x1 = int(row[1][0].split(" ")[0])
            y1 = int(row[1][0].split(" ")[1])
            x2 = int(row[1][0].split(" ")[2])
            y2 = int(row[1][0].split(" ")[3])
            cv2.rectangle(img,(x1,y1),(x2,y2),(255,0,0), 2)
        plt.figure()
        plt.imshow(img)
        break
# Out:
# airplane_167.jpg

# %%
cv2.setUseOptimized(True);
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

# %%
im = cv2.imread(os.path.join(path,"42850.jpg"))
ss.setBaseImage(im)
ss.switchToSelectiveSearchFast()
rects = ss.process()
imOut = im.copy()
for i, rect in (enumerate(rects)):
    x, y, w, h = rect
#     print(x,y,w,h)
#     imOut = imOut[x:x+w,y:y+h]
    cv2.rectangle(imOut, (x, y), (x+w, y+h), (0, 255, 0), 1, cv2.LINE_AA)
# plt.figure()
plt.imshow(imOut)

# %%
train_images=[]
train_labels=[]

# %%
def get_iou(bb1, bb2):
    assert bb1['x1'] < bb1['x2']
    assert bb1['y1'] < bb1['y2']
    assert bb2['x1'] < bb2['x2']
    assert bb2['y1'] < bb2['y2']

    x_left = max(bb1['x1'], bb2['x1'])
    y_top = max(bb1['y1'], bb2['y1'])
    x_right = min(bb1['x2'], bb2['x2'])
    y_bottom = min(bb1['y2'], bb2['y2'])

    if x_right < x_left or y_bottom < y_top:
        return 0.0

    intersection_area = (x_right - x_left) * (y_bottom - y_top)

    bb1_area = (bb1['x2'] - bb1['x1']) * (bb1['y2'] - bb1['y1'])
    bb2_area = (bb2['x2'] - bb2['x1']) * (bb2['y2'] - bb2['y1'])

    iou = intersection_area / float(bb1_area + bb2_area - intersection_area)
    assert iou >= 0.0
    assert iou <= 1.0
    return iou

# %%
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

# %%
count=0
for e,i in enumerate(os.listdir(annot)):
    count=count+1
    if(count==200):
      break
    try:
        if i.startswith("airplane"):
            filename = i.split(".")[0]+".jpg"
            print(e,filename)
            image = cv2.imread(os.path.join(path,filename))
            df = pd.read_csv(os.path.join(annot,i))
            gtvalues=[]
            for row in df.iterrows():
                x1 = int(row[1][0].split(" ")[0])
                y1 = int(row[1][0].split(" ")[1])
                x2 = int(row[1][0].split(" ")[2])
                y2 = int(row[1][0].split(" ")[3])
                gtvalues.append({"x1":x1,"x2":x2,"y1":y1,"y2":y2})
            ss.setBaseImage(image)
            ss.switchToSelectiveSearchFast()
            ssresults = ss.process()
            imout = image.copy()
            counter = 0
            falsecounter = 0
            flag = 0
            fflag = 0
            bflag = 0
            for e,result in enumerate(ssresults):
                if e < 2000 and flag == 0:
                    for gtval in gtvalues:
                        x,y,w,h = result
                        iou = get_iou(gtval,{"x1":x,"x2":x+w,"y1":y,"y2":y+h})
                        if counter < 30:
                            if iou > 0.70:
                                timage = imout[y:y+h,x:x+w]
                                resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                                train_images.append(resized)
                                train_labels.append(1)
                                counter += 1
                        else :
                            fflag =1
                        if falsecounter <30:
                            if iou < 0.3:
                                timage = imout[y:y+h,x:x+w]
                                resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                                train_images.append(resized)
                                train_labels.append(0)
                                falsecounter += 1
                        else :
                            bflag = 1
                    if fflag == 1 and bflag == 1:
                        print("inside")
                        flag = 1
    except Exception as e:
        print(e)
        print("error in "+filename)
        continue
# Out:
# 0 airplane_167.jpg
# 1 airplane_069.jpg
# 2 airplane_181.jpg
# 3 airplane_247.jpg
# 4 airplane_166.jpg
# 5 airplane_030.jpg
# 6 airplane_031.jpg
# 7 airplane_049.jpg
# 8 airplane_082.jpg
# 9 airplane_037.jpg
# 10 airplane_093.jpg
# 11 airplane_025.jpg
# 12 airplane_228.jpg
# 13 airplane_135.jpg
# 14 airplane_179.jpg
# 15 airplane_264.jpg
# inside
# 16 airplane_318.jpg
# 17 airplane_090.jpg
# 18 airplane_067.jpg
# 19 airplane_102.jpg
# 20 airplane_315.jpg
# inside
# 22 airplane_148.jpg
# 23 airplane_216.jpg
# 24 airplane_096.jpg
# inside
# 25 airplane_061.jpg
# 27 airplane_091.jpg
# 28 airplane_132.jpg
# 29 airplane_277.jpg
# 31 airplane_190.jpg
# inside
# 32 airplane_222.jpg
# 33 airplane_149.jpg
# 34 airplane_266.jpg
# 35 airplane_198.jpg
# 36 airplane_029.jpg
# 37 airplane_218.jpg
# 38 airplane_182.jpg
# 39 airplane_083.jpg
# inside
# 40 airplane_134.jpg
# 41 airplane_128.jpg
# 42 airplane_200.jpg
# 43 airplane_281.jpg
# 44 airplane_009.jpg
# 45 airplane_268.jpg
# 46 airplane_039.jpg
# 47 airplane_131.jpg
# 48 airplane_172.jpg
# 50 airplane_019.jpg
# 51 airplane_113.jpg
# 52 airplane_004.jpg
# inside
# 53 airplane_103.jpg
# 55 airplane_115.jpg
# 56 airplane_224.jpg
# 58 airplane_174.jpg
# 59 airplane_254.jpg
# 60 airplane_289.jpg
# inside
# 64 airplane_276.jpg
# inside
# 65 airplane_016.jpg
# 66 airplane_212.jpg
# 68 airplane_032.jpg
# 69 airplane_191.jpg
# 70 airplane_136.jpg
# inside
# 71 airplane_219.jpg
# 72 airplane_155.jpg
# 73 airplane_265.jpg
# 74 airplane_046.jpg
# 75 airplane_104.jpg
# 76 airplane_094.jpg
# 77 airplane_206.jpg
# 78 airplane_063.jpg
# 79 airplane_298.jpg
# 80 airplane_294.jpg
# 81 airplane_014.jpg
# 82 airplane_175.jpg
# 83 airplane_088.jpg
# 84 airplane_107.jpg
# 85 airplane_261.jpg
# 86 airplane_313.jpg
# 87 airplane_161.jpg
# 88 airplane_012.jpg
# inside
# 89 airplane_256.jpg
# 90 airplane_236.jpg
# 92 airplane_018.jpg
# 93 airplane_050.jpg
# 94 airplane_299.jpg
# 95 airplane_194.jpg
# 97 airplane_147.jpg
# 98 airplane_154.jpg
# 99 airplane_295.jpg
# 100 airplane_142.jpg
# 101 airplane_284.jpg
# 102 airplane_106.jpg
# 103 airplane_095.jpg
# 104 airplane_310.jpg
# 105 airplane_164.jpg
# 108 airplane_314.jpg
# 109 airplane_250.jpg
# 110 airplane_141.jpg
# 111 airplane_300.jpg
# 112 airplane_109.jpg
# 113 airplane_047.jpg
# 114 airplane_267.jpg
# 115 airplane_201.jpg
# 116 airplane_245.jpg
# 117 airplane_146.jpg
# 118 airplane_301.jpg
# inside
# 119 airplane_118.jpg
# 120 airplane_076.jpg
# 121 airplane_121.jpg
# inside
# 122 airplane_100.jpg
# 123 airplane_278.jpg
# 124 airplane_116.jpg
# 125 airplane_098.jpg
# 126 airplane_040.jpg
# 127 airplane_235.jpg
# 128 airplane_120.jpg
# inside
# 129 airplane_185.jpg
# 130 airplane_211.jpg
# 131 airplane_225.jpg
# inside
# 132 airplane_178.jpg
# 133 airplane_297.jpg
# inside
# 134 airplane_145.jpg
# 135 airplane_234.jpg
# 136 airplane_253.jpg
# 137 airplane_151.jpg
# inside
# 138 airplane_089.jpg
# 139 airplane_290.jpg
# 140 airplane_055.jpg
# 141 airplane_108.jpg
# inside
# 142 airplane_111.jpg
# 143 airplane_303.jpg
# 145 airplane_068.jpg
# 146 airplane_008.jpg
# 147 airplane_057.jpg
# 148 airplane_035.jpg
# 149 airplane_159.jpg
# 150 airplane_163.jpg
# 151 airplane_080.jpg
# 152 airplane_022.jpg
# 153 airplane_306.jpg
# inside
# 154 airplane_065.jpg
# 156 airplane_139.jpg
# 157 airplane_209.jpg
# 158 airplane_124.jpg
# 160 airplane_051.jpg
# 161 airplane_220.jpg
# 162 airplane_233.jpg
# 163 airplane_126.jpg
# inside
# 164 airplane_184.jpg
# 165 airplane_010.jpg
# 166 airplane_227.jpg
# 167 airplane_013.jpg
# 168 airplane_249.jpg
# 170 airplane_158.jpg
# 171 airplane_260.jpg
# 172 airplane_207.jpg
# 173 airplane_210.jpg
# 174 airplane_072.jpg
# 175 airplane_283.jpg
# 176 airplane_002.jpg
# 178 airplane_248.jpg
# 180 airplane_092.jpg
# 182 airplane_285.jpg
# 183 airplane_165.jpg
# 184 airplane_240.jpg
# 185 airplane_279.jpg
# 186 airplane_097.jpg
# inside
# 187 airplane_221.jpg
# 189 airplane_015.jpg
# 190 airplane_187.jpg
# 191 airplane_043.jpg
# 192 airplane_003.jpg
# 193 airplane_168.jpg
# 194 airplane_208.jpg
# 195 airplane_077.jpg
# 196 airplane_056.jpg
# 197 airplane_269.jpg
# 198 airplane_125.jpg

# %%
X_new = np.array(train_images)
y_new = np.array(train_labels)

# %%
X_new.shape
# Out:
# (7707, 224, 224, 3)

# %%
from keras.layers import Dense
from keras import Model
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import VGG16

# %%
vggmodel = VGG16(weights='imagenet', include_top=True)
vggmodel.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layers in (vggmodel.layers)[:15]:
    print(layers)
    layers.trainable = False
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7fb720bc2cd0>
# <keras.layers.convolutional.Conv2D object at 0x7fb710382050>
# <keras.layers.convolutional.Conv2D object at 0x7fb716f47950>
# <keras.layers.pooling.MaxPooling2D object at 0x7fb7101647d0>
# <keras.layers.convolutional.Conv2D object at 0x7fb71016dfd0>
# <keras.layers.convolutional.Conv2D object at 0x7fb71017b550>
# <keras.layers.pooling.MaxPooling2D object at 0x7fb710189310>
# <keras.layers.convolutional.Conv2D object at 0x7fb7101b4290>
# <keras.layers.convolutional.Conv2D object at 0x7fb710194910>
# <keras.layers.convolutional.Conv2D object at 0x7fb71019ab90>
# <keras.layers.pooling.MaxPooling2D object at 0x7fb71018f150>
# <keras.layers.convolutional.Conv2D object at 0x7fb71019e850>
# <keras.layers.convolutional.Conv2D object at 0x7fb710122210>
# <keras.layers.convolutional.Conv2D object at 0x7fb71019e9d0>
# <keras.layers.pooling.MaxPooling2D object at 0x7fb71012a250>

# %%
X= vggmodel.layers[-2].output

# %%
predictions = Dense(2, activation="softmax")(X)

# %%
model_final = Model(vggmodel.input, predictions)

# %%
model_final.compile(loss = keras.losses.categorical_crossentropy, optimizer = 'adam', metrics=["accuracy"])

# %%
model_final.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense (Dense)                (None, 2)                 8194
# =================================================================
# Total params: 134,268,738
# Trainable params: 126,633,474
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

# %%
class MyLabelBinarizer(LabelBinarizer):
    def transform(self, y):
        Y = super().transform(y)
        if self.y_type_ == 'binary':
            return np.hstack((Y, 1-Y))
        else:
            return Y
    def inverse_transform(self, Y, threshold=None):
        if self.y_type_ == 'binary':
            return super().inverse_transform(Y[:, 0], threshold)
        else:
            return super().inverse_transform(Y, threshold)

# %%
lenc = MyLabelBinarizer()
Y =  lenc.fit_transform(y_new)

# %%
X_train, X_test , y_train, y_test = train_test_split(X_new,Y,test_size=0.10)

# %%
trdata = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=90)
traindata = trdata.flow(x=X_train, y=y_train)
tsdata = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=90)
testdata = tsdata.flow(x=X_test, y=y_test)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
checkpoint = ModelCheckpoint("ieeercnn_vgg16_1.h5", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False)
early = EarlyStopping(monitor='val_loss', min_delta=0, patience=100, verbose=1, mode='auto')

# %%
#hist = model_final.fit_generator(generator= traindata, steps_per_epoch= 10, epochs= 1000, validation_data= testdata, validation_steps=2, callbacks=[checkpoint,early])

import tensorflow as tf
# run on GPU
with tf.device('/gpu:0'):
  hist = model_final.fit(traindata, steps_per_epoch= 10, epochs= 50, validation_data= testdata, validation_steps=2, callbacks=[checkpoint,early])
# Out:
# Epoch 1/50
# 10/10 [==============================] - 24s 675ms/step - loss: 234.1044 - accuracy: 0.5656 - val_loss: 1.0239 - val_accuracy: 0.7344
#
# Epoch 00001: val_loss improved from inf to 1.02390, saving model to ieeercnn_vgg16_1.h5
# Epoch 2/50
# 10/10 [==============================] - 8s 699ms/step - loss: 0.7727 - accuracy: 0.7000 - val_loss: 0.6320 - val_accuracy: 0.7344
#
# Epoch 00002: val_loss improved from 1.02390 to 0.63199, saving model to ieeercnn_vgg16_1.h5
# Epoch 3/50
# 10/10 [==============================] - 9s 639ms/step - loss: 0.6676 - accuracy: 0.6687 - val_loss: 0.6257 - val_accuracy: 0.6875
#
# Epoch 00003: val_loss improved from 0.63199 to 0.62573, saving model to ieeercnn_vgg16_1.h5
# Epoch 4/50
# 10/10 [==============================] - 6s 619ms/step - loss: 0.6168 - accuracy: 0.7063 - val_loss: 0.4874 - val_accuracy: 0.8438
#
# Epoch 00004: val_loss improved from 0.62573 to 0.48740, saving model to ieeercnn_vgg16_1.h5
# Epoch 5/50
# 10/10 [==============================] - 6s 636ms/step - loss: 0.5976 - accuracy: 0.7219 - val_loss: 1.3281 - val_accuracy: 0.7031
#
# Epoch 00005: val_loss did not improve from 0.48740
# Epoch 6/50
# 10/10 [==============================] - 14s 2s/step - loss: 0.7611 - accuracy: 0.6282 - val_loss: 0.5601 - val_accuracy: 0.7188
#
# Epoch 00006: val_loss did not improve from 0.48740
# Epoch 7/50
# 10/10 [==============================] - 7s 730ms/step - loss: 1.7815 - accuracy: 0.6094 - val_loss: 0.6335 - val_accuracy: 0.6562
#
# Epoch 00007: val_loss did not improve from 0.48740
# Epoch 8/50
# 10/10 [==============================] - 7s 719ms/step - loss: 0.8727 - accuracy: 0.6844 - val_loss: 0.6364 - val_accuracy: 0.7812
#
# Epoch 00008: val_loss did not improve from 0.48740
# Epoch 9/50
# 10/10 [==============================] - 7s 714ms/step - loss: 0.6797 - accuracy: 0.6438 - val_loss: 0.6441 - val_accuracy: 0.7188
#
# Epoch 00009: val_loss did not improve from 0.48740
# Epoch 10/50
# 10/10 [==============================] - 6s 625ms/step - loss: 0.6845 - accuracy: 0.6125 - val_loss: 0.6440 - val_accuracy: 0.7031
#
# Epoch 00010: val_loss did not improve from 0.48740
# Epoch 11/50
# 10/10 [==============================] - 6s 618ms/step - loss: 0.6697 - accuracy: 0.6827 - val_loss: 0.6192 - val_accuracy: 0.7500
#
# Epoch 00011: val_loss did not improve from 0.48740
# Epoch 12/50
# 10/10 [==============================] - 6s 630ms/step - loss: 0.7548 - accuracy: 0.5250 - val_loss: 0.6253 - val_accuracy: 0.7344
#
# Epoch 00012: val_loss did not improve from 0.48740
# Epoch 13/50
# 10/10 [==============================] - 6s 625ms/step - loss: 0.6585 - accuracy: 0.6656 - val_loss: 0.6289 - val_accuracy: 0.7656
#
# Epoch 00013: val_loss did not improve from 0.48740
# Epoch 14/50
# 10/10 [==============================] - 6s 628ms/step - loss: 0.6568 - accuracy: 0.6625 - val_loss: 0.6101 - val_accuracy: 0.7500
#
# Epoch 00014: val_loss did not improve from 0.48740
# Epoch 15/50
# 10/10 [==============================] - 6s 628ms/step - loss: 0.6664 - accuracy: 0.6875 - val_loss: 0.6394 - val_accuracy: 0.7812
#
# Epoch 00015: val_loss did not improve from 0.48740
# Epoch 16/50
# 10/10 [==============================] - 6s 627ms/step - loss: 0.6487 - accuracy: 0.6750 - val_loss: 0.6070 - val_accuracy: 0.7344
#
# Epoch 00016: val_loss did not improve from 0.48740
# Epoch 17/50
# 10/10 [==============================] - 6s 632ms/step - loss: 0.6413 - accuracy: 0.6594 - val_loss: 0.5542 - val_accuracy: 0.7812
#
# Epoch 00017: val_loss did not improve from 0.48740
# Epoch 18/50
# 10/10 [==============================] - 6s 625ms/step - loss: 0.5959 - accuracy: 0.7000 - val_loss: 0.6131 - val_accuracy: 0.6562
#
# Epoch 00018: val_loss did not improve from 0.48740
# Epoch 19/50
# 10/10 [==============================] - 6s 623ms/step - loss: 0.6177 - accuracy: 0.6344 - val_loss: 0.6009 - val_accuracy: 0.6406
#
# Epoch 00019: val_loss did not improve from 0.48740
# Epoch 20/50
# 10/10 [==============================] - 6s 631ms/step - loss: 0.5515 - accuracy: 0.7000 - val_loss: 0.5390 - val_accuracy: 0.6719
#
# Epoch 00020: val_loss did not improve from 0.48740
# Epoch 21/50
# 10/10 [==============================] - 6s 629ms/step - loss: 0.6079 - accuracy: 0.6125 - val_loss: 0.6593 - val_accuracy: 0.5781
#
# Epoch 00021: val_loss did not improve from 0.48740
# Epoch 22/50
# 10/10 [==============================] - 6s 622ms/step - loss: 0.6803 - accuracy: 0.6125 - val_loss: 0.5947 - val_accuracy: 0.7500
#
# Epoch 00022: val_loss did not improve from 0.48740
# Epoch 23/50
# 10/10 [==============================] - 6s 627ms/step - loss: 0.6613 - accuracy: 0.6438 - val_loss: 0.6314 - val_accuracy: 0.6875
#
# Epoch 00023: val_loss did not improve from 0.48740
# Epoch 24/50
# 10/10 [==============================] - 6s 629ms/step - loss: 0.6414 - accuracy: 0.6438 - val_loss: 0.5913 - val_accuracy: 0.7656
#
# Epoch 00024: val_loss did not improve from 0.48740
# Epoch 25/50
# 10/10 [==============================] - 6s 626ms/step - loss: 0.6008 - accuracy: 0.6906 - val_loss: 0.5625 - val_accuracy: 0.6875
#
# Epoch 00025: val_loss did not improve from 0.48740
# Epoch 26/50
# 10/10 [==============================] - 6s 630ms/step - loss: 0.5566 - accuracy: 0.6875 - val_loss: 0.5677 - val_accuracy: 0.7656
#
# Epoch 00026: val_loss did not improve from 0.48740
# Epoch 27/50
# 10/10 [==============================] - 6s 627ms/step - loss: 0.5561 - accuracy: 0.7031 - val_loss: 0.5771 - val_accuracy: 0.7188
#
# Epoch 00027: val_loss did not improve from 0.48740
# Epoch 28/50
# 10/10 [==============================] - 6s 626ms/step - loss: 0.5532 - accuracy: 0.7656 - val_loss: 0.6257 - val_accuracy: 0.7031
#
# Epoch 00028: val_loss did not improve from 0.48740
# Epoch 29/50
# 10/10 [==============================] - 6s 625ms/step - loss: 0.6001 - accuracy: 0.6938 - val_loss: 0.5445 - val_accuracy: 0.6719
#
# Epoch 00029: val_loss did not improve from 0.48740
# Epoch 30/50
# 10/10 [==============================] - 6s 631ms/step - loss: 0.5323 - accuracy: 0.7312 - val_loss: 0.6249 - val_accuracy: 0.6875
#
# Epoch 00030: val_loss did not improve from 0.48740
# Epoch 31/50
# 10/10 [==============================] - 6s 627ms/step - loss: 0.5522 - accuracy: 0.7063 - val_loss: 0.5122 - val_accuracy: 0.7656
#
# Epoch 00031: val_loss did not improve from 0.48740
# Epoch 32/50
# 10/10 [==============================] - 6s 626ms/step - loss: 0.5844 - accuracy: 0.6438 - val_loss: 0.6672 - val_accuracy: 0.6094
#
# Epoch 00032: val_loss did not improve from 0.48740
# Epoch 33/50
# 10/10 [==============================] - 6s 623ms/step - loss: 0.6516 - accuracy: 0.7000 - val_loss: 0.6819 - val_accuracy: 0.5938
#
# Epoch 00033: val_loss did not improve from 0.48740
# Epoch 34/50
# 10/10 [==============================] - 6s 626ms/step - loss: 0.6135 - accuracy: 0.6969 - val_loss: 0.6962 - val_accuracy: 0.6094
#
# Epoch 00034: val_loss did not improve from 0.48740
# Epoch 35/50
# 10/10 [==============================] - 6s 624ms/step - loss: 0.5876 - accuracy: 0.6875 - val_loss: 0.6337 - val_accuracy: 0.6250
#
# Epoch 00035: val_loss did not improve from 0.48740
# Epoch 36/50
# 10/10 [==============================] - 6s 619ms/step - loss: 0.5561 - accuracy: 0.7147 - val_loss: 0.5507 - val_accuracy: 0.7188
#
# Epoch 00036: val_loss did not improve from 0.48740
# Epoch 37/50
# 10/10 [==============================] - 6s 620ms/step - loss: 0.5743 - accuracy: 0.6906 - val_loss: 0.5702 - val_accuracy: 0.6875
#
# Epoch 00037: val_loss did not improve from 0.48740
# Epoch 38/50
# 10/10 [==============================] - 6s 625ms/step - loss: 0.5970 - accuracy: 0.7406 - val_loss: 0.5465 - val_accuracy: 0.7344
#
# Epoch 00038: val_loss did not improve from 0.48740
# Epoch 39/50
# 10/10 [==============================] - 6s 626ms/step - loss: 0.5307 - accuracy: 0.7406 - val_loss: 1.2509 - val_accuracy: 0.8125
#
# Epoch 00039: val_loss did not improve from 0.48740
# Epoch 40/50
# 10/10 [==============================] - 6s 634ms/step - loss: 0.5734 - accuracy: 0.7344 - val_loss: 0.6770 - val_accuracy: 0.6562
#
# Epoch 00040: val_loss did not improve from 0.48740
# Epoch 41/50
# 10/10 [==============================] - 6s 622ms/step - loss: 0.5572 - accuracy: 0.6875 - val_loss: 0.5014 - val_accuracy: 0.7188
#
# Epoch 00041: val_loss did not improve from 0.48740
# Epoch 42/50
# 10/10 [==============================] - 6s 623ms/step - loss: 0.5442 - accuracy: 0.7188 - val_loss: 0.4175 - val_accuracy: 0.8125
#
# Epoch 00042: val_loss improved from 0.48740 to 0.41753, saving model to ieeercnn_vgg16_1.h5
# Epoch 43/50
# 10/10 [==============================] - 6s 635ms/step - loss: 0.4839 - accuracy: 0.7719 - val_loss: 0.4636 - val_accuracy: 0.8125
#
# Epoch 00043: val_loss did not improve from 0.41753
# Epoch 44/50
# 10/10 [==============================] - 7s 728ms/step - loss: 0.5242 - accuracy: 0.7469 - val_loss: 0.4457 - val_accuracy: 0.7812
#
# Epoch 00044: val_loss did not improve from 0.41753
# Epoch 45/50
# 10/10 [==============================] - 7s 748ms/step - loss: 0.5228 - accuracy: 0.7500 - val_loss: 0.4980 - val_accuracy: 0.7812
#
# Epoch 00045: val_loss did not improve from 0.41753
# Epoch 46/50
# 10/10 [==============================] - 7s 723ms/step - loss: 0.4842 - accuracy: 0.7469 - val_loss: 0.4441 - val_accuracy: 0.7812
#
# Epoch 00046: val_loss did not improve from 0.41753
# Epoch 47/50
# 10/10 [==============================] - 7s 724ms/step - loss: 0.5503 - accuracy: 0.7281 - val_loss: 0.4024 - val_accuracy: 0.8125
#
# Epoch 00047: val_loss improved from 0.41753 to 0.40240, saving model to ieeercnn_vgg16_1.h5
# Epoch 48/50
# 10/10 [==============================] - 6s 632ms/step - loss: 0.6085 - accuracy: 0.6731 - val_loss: 0.7086 - val_accuracy: 0.5469
#
# Epoch 00048: val_loss did not improve from 0.40240
# Epoch 49/50
# 10/10 [==============================] - 7s 727ms/step - loss: 1.2092 - accuracy: 0.6844 - val_loss: 1.5618 - val_accuracy: 0.5000
#
# Epoch 00049: val_loss did not improve from 0.40240
# Epoch 50/50
# 10/10 [==============================] - 8s 845ms/step - loss: 0.8238 - accuracy: 0.6156 - val_loss: 0.7569 - val_accuracy: 0.7188
#
# Epoch 00050: val_loss did not improve from 0.40240

# %%
import matplotlib.pyplot as plt
# plt.plot(hist.history["acc"])
# plt.plot(hist.history['val_acc'])
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title("model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Loss","Validation Loss"])
plt.show()
plt.savefig('chart loss.png')

# %%
im = X_test[4]
plt.imshow(im)
img = np.expand_dims(im, axis=0)
out= model_final.predict(img)
if out[0][0] > out[0][1]:
    print("plane")
else:
    print("not plane")
# Out:
# not plane

# %%
z=0
for e,i in enumerate(os.listdir(path)):
    if i.startswith("4"):
        z += 1
        img = cv2.imread(os.path.join(path,i))
        ss.setBaseImage(img)
        ss.switchToSelectiveSearchFast()
        ssresults = ss.process()
        imout = img.copy()
        for e,result in enumerate(ssresults):
            if e < 2000:
                x,y,w,h = result
                timage = imout[y:y+h,x:x+w]
                resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                img = np.expand_dims(resized, axis=0)
                out= model_final.predict(img)
                if out[0][0] > 0.65:
                    cv2.rectangle(imout, (x, y), (x+w, y+h), (0, 255, 0), 1, cv2.LINE_AA)
        plt.figure()
        plt.imshow(imout)
